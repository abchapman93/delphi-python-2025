# %% [markdown]
# <img src="https://raw.githubusercontent.com/abchapman93/delphi-python-2025-dev/refs/heads/main/media/DELPHI-long.png">
# </br>
#
# <h1 valign="center" align="center"><font size="+150">Introduction to Python</br>December 2025</font></h1>

# %% [markdown]
# # Module 1
# Welcome to DELPHI Introduction to Python workshop! This class will use **Jupyter Notebooks** for writing code, running it on data, and viewing the results. Each day will start with a **Roadmap** that will outline the plans for the day.
#
# The general outline for each day will be:
# 1. Introduction of today's topic and review what we learned the day before
# 2. Learn the skills of the day by completing educational notebooks
# 3. Apply our new skills to a use case of pneumonia
#
# ## Overview
# In this module, we'll learn the Python essentials. We'll start with basic syntax and how to run code in Jupyter notebooks. Next, we'll learn how to use built-in **functions** and how to define **variables** . These will be two of the most important building blocks for using Python. Variables have different **data types**, which we'll delve into more in the second notebook which covers **strings**, **lists**, and other data structures. Then we'll start to really delve into the logic of Python programming by writing our own functions, using **for loops**, and executing **control statements**.

# %% [markdown]
# ## Outline
# 1. Python Essentials
# 2. Manipulating Data
# 3. Data Structures
# 4. Module 1 Exercises

# %% [markdown]
# ## TODO and Discussion items
# Throughout these notebooks, you'll see sections marked **TODO** or **Discussion**. Whenever you see a todo section, you'll be asked to edit or complete code. Parts of code which you need to edit will have placeholders of three underscores: `___`. You should replace these underscores with the correct snippet of code. This syntax should be familiar with you as the convention used by DataCamp.
#
# For example, if you are asked to edit the cell below to print out the text "Hello, world!", you should change this cell (which won't run correctly until you change it):

# %%
___("Hello, world!")

# %% [markdown]
# To this:

# %%
print("Hello, world!")

# %% [markdown]
# ## Helper code
# I've written some helper code for the workshop. Run the next two cells and make sure you don't get any errors (we'll do this step in every new notebook)

# %%
# !pip install https://github.com/abchapman93/delphi-python-2025/releases/download/dev/uu_delphi_python_dec25-0.1.tar.gz

# %%
from uu_delphi_python_dec25 import *
from uu_delphi_python_dec25.quizzes.module1_quizzes import *

# %% [markdown]
# ## Quizzes and Unit Tests
# Some of the **TODO** items will use widgets or test functions that I've made for the class. Here are some examples:

# %% [markdown]
# ### 1. Multiple Choice
# Multiple choice quizzes will give you several answers. One of them is correct.

# %%
# RUN CELL TO SEE QUIZ
test_day_of_week

# %% [markdown]
# ### 2. Select Multiple
# These quizzes will have one or more correct answers. Hold "Command" (Mac) or "Ctrl" (windows) to add another option to your selection.

# %%
prime_mc

# %% [markdown]
# ### 3. Free Text
# Free text quizzes will ask you two write a free-text value. It has to be entered exactly as expected (case insensitive), so try to follow the suggestions for how to write it.

# %%
# RUN CELL TO SEE QUIZ
test_state

# %% [markdown]
# ### 4. Function test
# Here you'll enter the name of the function and it will test whether the function returns the expected value. For example, the following test checks whether the built-in function `max` returns the largest value in an array. (This will make more sense at the end of the day!)

# %%
# RUN CELL TO TEST VALUE
test_max.test(max)

# %% [markdown]
# **4. Value test**: This tests whether the value of a variable is what was expected.

# %%
x = 3
x

# %%
test_x_equals_3.test(3)

# %% [markdown]
# ### 5. Hints
# Some exercises will offer hints which you can check if you need help getting start with an answer or if the exercise is a visualization which can't be checked manually.

# %%
hint_example

# %% [markdown]
# ## AI and coding paradigms
# This is my first time teaching a workshop since LLMs became helpful for coding. So I'm going to be learning with you the best way to use them how for coding an education. In general, we'll switch back and forth between three paradigms of writing code.
#
# <img class="center-img" src="https://github.com/abchapman93/delphi-python-2025-dev/blob/main/media/three_coding_icons.png?raw=true" width="750" style="display: block; margin: auto;" >
# </br>
#
# 1. **Old school**: Completely manual, no AI allowed!
# 2. **Vibe coding**: Only code by prompting AI.
# 3. **AI Assist**: Work collaboratively with an AI to write and improve code.
#
# If you see one of these icons next to an exercise, then stick to that paradigm for that exercise.
# To get started, let's jump into an exercise where we'll try out all three of these paradigms.

# %% [markdown]
# ### First coding exercises

# %% [markdown]
# #### Step 1.
# <img class="center-img" src="https://raw.githubusercontent.com/abchapman93/delphi-python-2025-dev/refs/heads/main/media/coding_icon1_old_school.png" width="100">
#
# We're going to start by manually writing some simple code to print a simple greeting to a user. Edit the cells below, following the instructions in comments.

# %% [markdown]
# First, we're going to *declare variables* that represent the user's first and last names, with an option for printing out their middle name. Edit the cell below with your information.

# %%
first_name = "Alec" # Edit the string (in quotes) to be your first name
last_name = "Chapman" # Edit the string to be your last name and assign to an appropriately named variable
middle_name = "" # Change this to your middle name if you have one - otherwise, leave it as it is

# %% [markdown]
# Now, we're going to print out a message using the `print` function:

# %%
print(f"Hello, {first_name} {middle_name} {last_name}!")

# %% [markdown]
# #### Step 2.
#
# <img class="center-img" src="https://raw.githubusercontent.com/abchapman93/delphi-python-2025-dev/refs/heads/main/media/coding_icon2_vibe.png" width="100">

# %% [markdown]
# Now let's tell Colab's built-in Gemini assistant (or whatever AI assistant you chose) to write its own version of the code. Write a prompt telling the agent what you want. Try to be as specific as you can. Once it generates code, first read through the block of code. Double-check that nothing problematic will happen and that it looks generally like what we asked it to do. Then execute the code and review the output. How did it do? Does it differ from our approach?

# %% [markdown]
# Since we're using all of AI's Python knowledge, let's be a little more ambitious. Let's ask Gemini to modify it's code to do the following:
#
# 1. Input the user's first, last, and optional name interactively.
# 2. Choose a greeting based on the time of day in US Mountain Time.
# 3. Print the current date.
# 4. Leave the user with an inspiring quote.
#
# When the AI is finished, read through the code it wrote as well as the explanations. Without having learned much about Python yet, can you understand the general logic? What do you notice about the syntax and structure of the code? Are the AI's explanations helpful?

# %% [markdown]
# #### c. AI-assist
#
# <img class="center-img" src="https://raw.githubusercontent.com/abchapman93/delphi-python-2025-dev/refs/heads/main/media/coding_icon3_collab.png" width="100">
#
#
# Using the AI's code as a starting point, let's make some adjustments:
#
# 1. Change the format of the date (e.g., use Month/Day/Year)
# 2. Print the time as well as the date.
# 3. Randomly sample from a set of 5 inspirational quotes.
#
#
# Do Step \#1 manually, without asking AI for help. Then ask the AI to modify the code for Step \#2. For Step \#3, write the code yourself, but you can ask AI for help with how to do it.
