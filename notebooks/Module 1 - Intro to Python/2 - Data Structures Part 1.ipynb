# %% [markdown]
# <img src="https://raw.githubusercontent.com/abchapman93/delphi-python-2025-dev/refs/heads/main/media/DELPHI-long.png">
# </br>
#
# <h1 valign="center" align="center"><font size="+150">Introduction to Python</br>December 2025</font></h1>

# %%
# !pip install https://github.com/abchapman93/delphi-python-2025/releases/download/dev/uu_delphi_python_dec25-0.1.tar.gz
# Out:
# Collecting https://github.com/abchapman93/delphi-python-2025/releases/download/dev/uu_delphi_python_dec25-0.1.tar.gz
#   Downloading https://github.com/abchapman93/delphi-python-2025/releases/download/dev/uu_delphi_python_dec25-0.1.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jupyter in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from uu_delphi_python_dec25==0.1) (1.1.1)
# Requirement already satisfied: numpy in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from uu_delphi_python_dec25==0.1) (2.3.5)
# Requirement already satisfied: pandas in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from uu_delphi_python_dec25==0.1) (2.3.3)
# Requirement already satisfied: notebook in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter->uu_delphi_python_dec25==0.1) (7.5.0)
# Requirement already satisfied: jupyter-console in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter->uu_delphi_python_dec25==0.1) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter->uu_delphi_python_dec25==0.1) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter->uu_delphi_python_dec25==0.1) (7.1.0)
# Requirement already satisfied: ipywidgets in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter->uu_delphi_python_dec25==0.1) (8.1.8)
# Requirement already satisfied: jupyterlab in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter->uu_delphi_python_dec25==0.1) (4.5.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (9.8.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (25.0)
# Requirement already satisfied: psutil>=5.7 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipykernel->jupyter->uu_delphi_python_dec25==0.1) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (4.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (3.0.1)
# Requirement already satisfied: pure_eval in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->uu_delphi_python_dec25==0.1) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipywidgets->jupyter->uu_delphi_python_dec25==0.1) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from ipywidgets->jupyter->uu_delphi_python_dec25==0.1) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (78.1.1)
# Requirement already satisfied: anyio in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (4.12.0)
# Requirement already satisfied: certifi in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.0.9)
# Requirement already satisfied: idna in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (0.1.1)
# Requirement already satisfied: fqdn in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.5.1)
# Requirement already satisfied: isoduration in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.1.0)
# Requirement already satisfied: uri-template in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from nbconvert->jupyter->uu_delphi_python_dec25==0.1) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->uu_delphi_python_dec25==0.1) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from nbconvert->jupyter->uu_delphi_python_dec25==0.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from nbconvert->jupyter->uu_delphi_python_dec25==0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from nbconvert->jupyter->uu_delphi_python_dec25==0.1) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from nbconvert->jupyter->uu_delphi_python_dec25==0.1) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from nbconvert->jupyter->uu_delphi_python_dec25==0.1) (1.5.1)
# Requirement already satisfied: webencodings in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->uu_delphi_python_dec25==0.1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->uu_delphi_python_dec25==0.1) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.0.0)
# Requirement already satisfied: pycparser in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->uu_delphi_python_dec25==0.1) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (1.4.0)
# Requirement already satisfied: tzdata in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->uu_delphi_python_dec25==0.1) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alecchapman/Code/DELPHI/delphi-python-2025-dev/.conda/lib/python3.11/site-packages (from pandas->uu_delphi_python_dec25==0.1) (2025.2)

# %%
from uu_delphi_python_dec25 import *
from uu_delphi_python_dec25.quizzes.module1_quizzes import *
from uu_delphi_python_dec25.helpers import *

# %% [markdown]
# # Data Structures Part 1
# In the previous notebook we learned about some of the essential data types in Python. We'll now dive deeper into Python's built-in **data structures**. A data structure is a type of object which helps us organize and access data. Each data structure is used for a slightly different purpose and has different methods associated with it.
#
#
# The four data types we'll look at in the next two notebooks are:
# - I. `list`
# - II. `tuple`
# - III. `dict` (dictionary)
# - IV. `set`
#
# ## Lists
# The following are all lists in Python:

# %%
x = [1, 2, 3]
y = ["a", "b", "c"]
z = [1, "b", x]

# %% [markdown]
# #### TODO
# What are the data types of the three elements of `z` in the previous cell?

# %%
# RUN CELL TO SEE QUIZ
quiz_data_types_z
# Out:
# VBox(children=(HTML(value='What are the data types of the three elements of `z`?'), RadioButtons(layout=Layout…

# %% [markdown]
# Here are some things we might want to do with lists:
# 1. Access specific elements
# 2. Add or remove elements
# 3. Combine two different lists
# 4. Sorting and finding the min/max values

# %% [markdown]
# ### 1. Accessing specific elements
# Lists and the other data structures in this notebook are also called **containers** because they **contain** other objects. As such, one of the main purposes of a list is to store an object in it and access it later.
#
# The main way to do this with lists is **indexing**. Each element in a list has a numeric index - that is, its *ordered* position in a list. You do this by putting brackets after the name of the list and a numeric index. For example, let's say we want to access the first element of `x`. We would do this as:
#
# ```python
# x[0]
# ```
#
# This might look a little funny to you - the *zeroth* index of x? The reason that we use `x[0]` instead of `x[1]` for the first elementing is that Python uses **zero indexing**, meaning that the positions start at 0 and end at `len(x) - 1`. This is different from R or many other statistical software packages. You can think of this as saying: **Give me the element of x which is `0` positions away from the beginning**.

# %% [markdown]
# #### TODO
# What code would give you the second element of `x`?

# %%
# RUN CELL TO SEE QUIZ
quiz_second_element_x
# Out:
# VBox(children=(HTML(value='What code would give you the second element of `x`?'), Textarea(value='', placehold…

# %% [markdown]
# #### TODO
# What value would get if you ran the following line of code?
# ```python
# x[3]
# ```

# %%
# RUN CELL TO SEE QUIZ
quiz_x3
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('None', 'An error would be r…

# %% [markdown]
# To get the length of a list, we can use the built-in `len` function.

# %%
len(x)
# Out:
# 3

# %% [markdown]
# #### TODO
# What is the largest value of `idx` we could use in the code `x[idx]`?

# %%
# RUN CODE TO SEE QUIZ
quiz_largest_idx_x
# Out:
# VBox(children=(HTML(value=''), Textarea(value='', placeholder='Type something'), Button(description='Submit', …

# %% [markdown]
# #### `k` steps back
# When we pass in 0 or a positive index `k` for list `x`, we go `k` positions from the beginning. But if we pass in a negative number, we go backwards from the end of the list. So one way to get the last element of `x` is:

# %%
x[-1]
# Out:
# 3

# %%
x
# Out:
# [1, 2, 3]

# %% [markdown]
# #### TODO
# Which of the following lines of code would give you the second-to-last element of x?
# - a) `x[-2]`
# - b) `x[1]`
# - c) `x[len(x)-2]`

# %%
# RUN CELL TO SEE QUIZ
quiz_second_to_last_x
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('a)', 'b)', 'c)', 'All of th…

# %% [markdown]
# Note that in our example lists, the last element of `z` is the list `x`.

# %%
z
# Out:
# [1, 'b', [1, 2, 3]]

# %% [markdown]
# #### TODO
# Which of the following lines of code would give the value `2`?
# - a) `x[1]`
# - b) `x[-2]`
# - c) `z[3]`
# - d) `z[-1][-2]`

# %%
# RUN CELL TO SEE QUIZ
quiz_values_of_2
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('a), b), and d)', 'a) and c)…

# %% [markdown]
# If we a subset of a list (that is, a smaller list containing some of the elements of the larger list), we use the following notation:
#
# ```python
# x[start:end]
# ```
#
# This will give us a list containing `[x[start], x[start+1], ..., x[end-1]]`
#
# **Question**: Why will the sublist end at `x[end-1]`?

# %% [markdown]
# #### TODO
# Create a smaller list containing only the second and third elements of `x`. Name it `x_sub1`.

# %%
[x[1], x[2]]
# Out:
# [2, 3]

# %%
x_sub1 = x[1:3]
x_sub1
# Out:
# [2, 3]

# %%
# RUN CELL TO TEST VALUE
test_x_sub1.test(x_sub1)
# Out:
# That is correct!

# %% [markdown]
# If we leave out the `start` index, then the sublist will contain all of the elements of `x` from the beginning until `end-1`:

# %%
x[:2]
# Out:
# [1, 2]

# %% [markdown]
# Similarly, if we leave out the `end` index, the sublist will contain all elements from `start` through the end of the list:

# %%
x[1:]
# Out:
# [2, 3]

# %% [markdown]
# #### TODO
# What list would be created with the code `x[:]`. Why?

# %%
# RUN CELL TO SEE QUIZ
quiz_x_colon
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('An error will be raised.', …

# %% [markdown]
# ### 2. Adding or removing elements
# Often the containers we're using aren't static. We might update them by adding new objects to them or removing some. Next we'lllook at a few methods for doing this.
#
# **Methods** are like functions but are associated with a particular object. Calling a method looks similar to calling a function but comes from the object:
#
# ```python
# obj.method_name(args)
# ```
#
# For example, lists have a method called `append` that adds an element to the end of the list. This method takes one argument, which is the object we want to add to the list.
#
# For example, let's say we had a list of names for patients in the emergency department. We'll call this list `waiting_list`. When a new patient shows up, we need to **append** their name to the list.

# %%
waiting_list = ["Jim", "Mary", "Rachel"]
waiting_list.append("Laura")

# %%
type(waiting_list)
# Out:
# list

# %%
waiting_list
# Out:
# ['Jim', 'Mary', 'Rachel', 'Laura']

# %% [markdown]
# Now when we look at this object, we can see that "Laura" is also in our queue.

# %%
waiting_list
# Out:
# ['Jim', 'Mary', 'Rachel', 'Laura']

# %% [markdown]
# But let's say that someone named **"Chloe"** comes in who is much sicker than the other patients and needs to be seen with higher priority. We can add an element to a specific position in a list by using the `insert` method. This takes two arguments: the index of the list where you want to put the new object, and the object itself.
#
# So, for example, the line below will add `"Chloe"` to the beginning of the list.

# %%
waiting_list.insert(0, "Chloe")

# %%
waiting_list
# Out:
# ['Chloe', 'Jim', 'Mary', 'Rachel', 'Laura']

# %% [markdown]
# Eventually, the understaffed doctors in the emergency room are ready to see a patient. To remove an object from a specific position we can use the `pop` method. This takes one argment, the index of the element to remove. Since our queue is already in the order we want to see the patients, we pass in `0` as the index.
#
# This also returns the removed object, so we can save that as a variable to see who the next patient is.

# %%
next_patient = waiting_list.pop(0)
print(f"Next up: {next_patient}")
# Out:
# Next up: Chloe

# %%
waiting_list
# Out:
# ['Jim', 'Mary', 'Rachel', 'Laura']

# %% [markdown]
# #### TODO
# What would be the value of `next_patient` if you ran the previous cell again?

# %%
# RUN CELL TO SEE QUIZ
quiz_next_patient2
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('Jim', 'Mary', 'Rachel', 'Ch…

# %% [markdown]
# #### TODO
# Let's say someone named **"Jacob"** comes into the ER. At first they don't seem too sick, so we put them at the end of the queue. Write the code below to add `"Jacob"` to the end of `waiting_list`.

# %%
____

# %%
# RUN CELL TO TEST VALUE
test_waiting_list_jacob.test(waiting_list)
# Out:
# That is correct!

# %% [markdown]
# #### TODO
# After being added to the end of the queue, Jacob's condition suddenly worsens and he needs to be seen immediately. Remove Jacob's name from the list and save it as `next_patient`.

# %%
____ = ____

# %%
next_patient
# Out:
# 'Jacob'

# %%
# RUN CELL TO TEST VALUE
test_next_patient3.test(next_patient)
# Out:
# That is correct!

# %% [markdown]
# After running the code above, what is the value of `len(waiting_list)`?

# %%
# RUN CELL TO SEE QUIZ
test_len_waiting_list
# Out:
# VBox(children=(HTML(value=''), Textarea(value='', placeholder='Type something'), Button(description='Submit', …

# %% [markdown]
# ### 3. Combing two different lists
# In addition to adding individual elements, we can also take two different lists and combine them. This is called **concatenation**.
#
# There are two ways to do this: First by using the addition operator `+`. For example, to combine the elements of `x` and `y` into one new list, we could do:

# %%
x + y
# Out:
# [1, 2, 3, 'a', 'b', 'c']

# %% [markdown]
# This creates a *new list* containing the elements of `x` followed by the elements of `y`. But the original lists are not altered:

# %%
x
# Out:
# [1, 2, 3]

# %% [markdown]
# The second option is the method `extend` which modifies the list directly. So if you called:
#
# ```pythong
# x.extend(y)
# print(x)
# ```
#
# You would see the new, longer list: `[1, 2, 3, 'a', 'b', 'c']`
#
# I prefer not altering original objects whenever possible, so I personally recommend using the `+` operator. You can also update the value of x accordingly by saying:
#
# ```python
# x += y
# print(x)
# # [1, 2, 3, 'a', 'b', 'c']
# ```

# %% [markdown]
# #### TODO
# Below are three lists: `a`, `b`, and `c`. Write code to do the following:
#
# 1. Create a new list `z` which contains the elements of `b` followed by the elements of `a`
# 2. Modify `c` directly to include the elements in `a` and `b` (in that order)

# %%
a = [1, 2, 3]
b = ["a", "b", "c"]
c = [2, 4, "6"]

# %%
____ = ____

# %%
#### Solution
z = b + a
z
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# RUN CELL TO TEST VALUE
test_list_a_added_to_b.test(z)
# Out:
# That is correct!

# %%
____

# %%
#### Solution
c += a # Add elements of a to c
c += b # Add elements of b to c

# %%
c
# Out:
# [2, 4, '6', 1, 2, 3, 'a', 'b', 'c']

# %%
# RUN CELL TO TEST VALUE
test_list_a_b_added_to_c.test(c)
# Out:
# That is correct!

# %% [markdown]
# ### 4. Sorting lists
# We may initially get data in completely arbitrary order. But it's often useful to sort them in some way.
#
# Again, there are two ways we can do this. First, the built-in function `sorted` takes a array and returns a new array containing the elements in ascending order:

# %%
my_list = [5, 2, 9]

# %%
sorted(my_list)
# Out:
# [2, 5, 9]

# %%
print(my_list)
# Out:
# [5, 2, 9]

# %% [markdown]
# We can also sort in descending order using the `reverse` argument:

# %%
sorted(my_list, reverse=True)
# Out:
# [9, 5, 2]

# %% [markdown]
# Once a list is sorted, we can use that to get identify the n smallest/largest numbers.
#
#
# #### TODO
# Use the `sorted` function to find the three smallest and three largest values of `random_list`. Save the values as lists with length 3 called `my_list_smallest` and `my_list_largest`, both in ascending order.

# %%
random_list = [87, 69, 56, 17, 80, 30, 29, 10, 88, 12, 88, 97, 89, 74, 97, 26, 13,
       88, 41, 22, 92, 26, 49, 46, 73]

# %%
random_list_smallest = ____
random_list_largest =  ____

# %%
random_list_smallest
# Out:
# [10, 12, 13]

# %%
# RUN CELL TO TEST VALUE
test_random_list_smallest.test(random_list_smallest)
# Out:
# That is correct!

# %%
random_list_largest
# Out:
# [92, 97, 97]

# %%
# RUN CELL TO TEST VALUE
test_random_list_largest.test(random_list_largest)
# Out:
# That is correct!

# %% [markdown]
# #### `min` and `max` function
# If you only need absolute smallest/largest values, you can use the `min` and `max` functions:

# %%
min(random_list)
# Out:
# 10

# %%
max(random_list)
# Out:
# 97

# %% [markdown]
# #### TODO
# Consider this list of strings:
#
# ```python
# waiting_list2 = ['Jim', 'Chloe',  'Mary', 'Rachel', 'Laura', 'Jacob']
# ```
#
# What values would we get if we called `min(waiting_list2)` and `max(waiting_list2)`?

# %%
# RUN CELL TO SEE QUIZ
quiz_min_max_waiting_list
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('An error would be raised.',…

# %% [markdown]
# ## II. Tuples
# Now we'll move onto a second type of data structure. We declare a **tuple** by separating values by commas within parentheses (as opposed to the squares brackets used for lists).

# %%
x_tup = (1, 2, 3)
x_tup
# Out:
# (1, 2, 3)

# %%
type(x)
# Out:
# list

# %% [markdown]
# Tuples are very similar to lists, except that they are **immutable**. That means once a tuple is declared, we can't modify it or its contents. This is useful if we know a collection of elements are fairly permanent and don't plan on altering them.
#
# So, for example, while with lists we could append an element to the end using `list.append(item)` and remove elements with `list.pop(i)`, with tuples we need to create a brand new object.

# %% [markdown]
# #### TODO
# What will happen when we run the code below?
# ```python
# x_tup.append(4)
# ```

# %%
# RUN CELL TO SEE QUIZ
quiz_tup_append
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('x_tup will equal (1,2,3,4)'…

# %% [markdown]
# #### TODO
# What will happen when we run the code below?
# ```python
# x_tup[1] = "a"
# ```

# %%
# RUN CODE TO SEE QUIZ
quiz_set_tup_index
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('A new tuple will be returne…

# %% [markdown]
# #### TODO
# Which line of code would cause the value of the variable `x_tup` to include the elements `4` and `5`?
#
# - a) `x_tup.extend((4,5))`
# - b) `x_tup += (4, 5)`
# - c) `x_tup.append(4); x_tup.append(5)`

# %%
quiz_x_tup_4_5
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('a', 'b', 'c', 'a and b', 'A…

# %% [markdown]
# Other than changing their contents, we can do a lot of the same things with tuples that we did with lists.
#
# We index them the same way:

# %%
x_tup[0]
# Out:
# 1

# %%
x_tup[-1]
# Out:
# 3

# %%
x_tup[1:]
# Out:
# (2, 3)

# %% [markdown]
# And we can gets the min and max sort them using the appropriate functions.

# %%
max(x_tup)
# Out:
# 3

# %%
min(x_tup)
# Out:
# 1

# %%
sorted(x_tup)
# Out:
# [1, 2, 3]

# %%
sorted(x_tup, reverse=True)
# Out:
# [3, 2, 1]

# %%
x_tuple2 = tuple(sorted(x_tup))
x_tuple2
# Out:
# (1, 2, 3)

# %% [markdown]
# #### TODO
# What data type is returned by `sorted(x_tup)`?

# %%
# RUN CODE TO SEE QUIZ
quiz_type_sorted_tup
# Out:
# VBox(children=(HTML(value=''), RadioButtons(layout=Layout(width='auto'), options=('tuple', 'list', 'other'), v…

# %% [markdown]
# We can create tuples from lists and vice-versa:

# %%
list(x_tup)
# Out:
# [1, 2, 3]

# %% [markdown]
# #### TODO
# Create a list called `x_list` from `x_tup`. What code would test whether `x_list` is equal to `x`? Are they equal? Does `x_list` equal `x_tup`?

# %%
____ = ____

# %%
# RUN CELL TO TEST VALUE
test_x_list.test(x_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # RUN CELL TO TEST VALUE
# ----> 2 test_x_list.test(x_list)
#
# NameError: name 'x_list' is not defined

# %%
# RUN CELL TO SEE QUIZ
quiz_x_equals_x_list
# Out:
# VBox(children=(HTML(value='Are x and x_list equal?'), RadioButtons(layout=Layout(width='auto'), options=('Yes'…

# %% [markdown]
# In the next notebook, we'll learn about *sets* and *dictionaries*.
